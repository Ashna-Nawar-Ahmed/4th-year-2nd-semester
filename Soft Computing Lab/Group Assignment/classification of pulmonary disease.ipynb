# %% [markdown]
# ## Seperating test image(10% of total image in each class)

# %%
import shutil
import os
import random
src='C:/Users/Raihan/Downloads/chestxray/pneumoniaResize/'
dst='C:/Users/Raihan/Downloads/chestxray/data/test/'

#os.makedirs(dst)
a=os.listdir(src)

numtoselect=int(len(a)*.1)


randomlist=random.sample(a,numtoselect)

for i in randomlist:
    shutil.move(src+i,dst)

# %% [markdown]
# ## Resizing Image

# %%
from PIL import Image
import glob
import os

# new folder path (may need to alter for Windows OS)
# change path to your path
path = 'C:/Users/Raihan/Downloads/chestxray/extra/resize/'
# create new folder
if not os.path.exists(path):
    os.makedirs(path)

# loop over existing images and resize
# change path to your path
for filename in glob.glob('C:/Users/Raihan/Downloads/chestxray/extra/*.png'):
    img = Image.open(filename).resize((400,400))
    # save resized images to new folder with existing filename
    img.save('{}{}{}'.format(path,'/',os.path.split(filename)[1]))

# %% [markdown]
# ## Making CSV for test images

# %%
import shutil
import os
import random
#src='C:/Users/Raihan/Downloads/chestxray/pneumoniaResize/'
src='C:/Users/Raihan/Downloads/chestxray/data/test/'
dst1='C:/Users/Raihan/Downloads/chestxray/data/covidTest/'
dst2='C:/Users/Raihan/Downloads/chestxray/data/normalTest/'
dst3='C:/Users/Raihan/Downloads/chestxray/data/LungOpacityTest/'
dst4='C:/Users/Raihan/Downloads/chestxray/data/pneumoniaTest/'
os.makedirs(dst1)
os.makedirs(dst2)
os.makedirs(dst3)
os.makedirs(dst4)
a=os.listdir(dst)

numtoselect=int(len(a)*.1)
cnt=0
cnt1=0
cnt2=0
cnt3=0
s='COVID-1003.png'
#if 'COVID' in s:
    #print('yes')
for i in a:
    if 'COVID' in i:
        cnt+=1
        shutil.copy(src+i,dst1)
    elif 'Normal' in  i:
        cnt1+=1
        shutil.copy(src+i,dst2)
    elif 'Lung_Opacity' in  i:
        cnt2+=1
        shutil.copy(src+i,dst3)
    elif 'pneumonia' in  i:
        cnt3+=1
        shutil.copy(src+i,dst4)
print(cnt,' ',cnt1,' ',cnt2,' ',cnt3)
# Out:
# 361   1019   601   387

# %%
import os
import pandas 
a=os.listdir('C:/Users/Raihan/Downloads/chestxray/data/LungOpacityTest/')
'''for i in a:
    print(i)
l=[]
'''

df = pandas.DataFrame(data={"imageid": a, "label": 3})
df.to_csv("C:/Users/Raihan/Downloads/chestxray/data/loTest.csv", sep=',',index=False)
df
# Out:
#                    imageid  label
# 0    Lung_Opacity-1000.png      3
# 1    Lung_Opacity-1018.png      3
# 2    Lung_Opacity-1031.png      3
# 3    Lung_Opacity-1055.png      3
# 4     Lung_Opacity-106.png      3
# ..                     ...    ...
# 596   Lung_Opacity-912.png      3
# 597    Lung_Opacity-96.png      3
# 598    Lung_Opacity-97.png      3
# 599   Lung_Opacity-982.png      3
# 600   Lung_Opacity-990.png      3
#
# [601 rows x 2 columns]

# %%
normalTCsv = pd.read_csv('C:/Users/Raihan/Downloads/chestxray/data/normalTest.csv')
normalTCsv.columns
normalTCsv.iloc[:10, 0:]
# Out:
#             imageid  label
# 0      Normal-1.png      0
# 1     Normal-10.png      0
# 2   Normal-1000.png      0
# 3  Normal-10001.png      0
# 4   Normal-1001.png      0
# 5  Normal-10013.png      0
# 6  Normal-10021.png      0
# 7  Normal-10027.png      0
# 8  Normal-10056.png      0
# 9  Normal-10075.png      0

# %%
covidTCsv = pd.read_csv('C:/Users/Raihan/Downloads/chestxray/data/covidTest.csv')
covidTCsv.columns
covidTCsv.iloc[:10, 0:]
# Out:
#           imageid  label
# 0  COVID-1003.png      1
# 1  COVID-1007.png      1
# 2  COVID-1016.png      1
# 3  COVID-1017.png      1
# 4   COVID-102.png      1
# 5  COVID-1021.png      1
# 6   COVID-103.png      1
# 7  COVID-1033.png      1
# 8  COVID-1039.png      1
# 9  COVID-1053.png      1

# %%
pneuTCsv = pd.read_csv('C:/Users/Raihan/Downloads/chestxray/data/pneumoniaTest.csv')
pneuTCsv.columns
pneuTCsv.iloc[:10, 0:]
# Out:
#               imageid  label
# 0  pneumonia1000.jpeg      2
# 1  pneumonia1002.jpeg      2
# 2  pneumonia1022.jpeg      2
# 3  pneumonia1035.jpeg      2
# 4  pneumonia1037.jpeg      2
# 5  pneumonia1038.jpeg      2
# 6   pneumonia106.jpeg      2
# 7  pneumonia1064.jpeg      2
# 8  pneumonia1072.jpeg      2
# 9   pneumonia109.jpeg      2

# %%
loTCsv = pd.read_csv('C:/Users/Raihan/Downloads/chestxray/data/loTest.csv')
loTCsv.columns
loTCsv.iloc[:10, 0:]
# Out:
#                  imageid  label
# 0  Lung_Opacity-1000.png      3
# 1  Lung_Opacity-1018.png      3
# 2  Lung_Opacity-1031.png      3
# 3  Lung_Opacity-1055.png      3
# 4   Lung_Opacity-106.png      3
# 5  Lung_Opacity-1060.png      3
# 6  Lung_Opacity-1066.png      3
# 7  Lung_Opacity-1067.png      3
# 8  Lung_Opacity-1075.png      3
# 9  Lung_Opacity-1085.png      3

# %%
PATH = 'C:/Users/Raihan/Downloads/chestxray/data/'

# %%
def showRawTrainingSamples(csv_filename):
    df = pd.read_csv(PATH + csv_filename)
    print(csv_filename)
    print(df.columns)
    return df

# %%
nT_csv = showRawTrainingSamples('normalTest.csv')
cT_csv = showRawTrainingSamples('covidTest.csv')
pT_csv = showRawTrainingSamples('pneumoniaTest.csv')
lT_csv = showRawTrainingSamples('loTest.csv')
# Out:
# normalTest.csv
# Index(['imageid', 'label'], dtype='object')
# covidTest.csv
# Index(['imageid', 'label'], dtype='object')
# pneumoniaTest.csv
# Index(['imageid', 'label'], dtype='object')
# loTest.csv
# Index(['imageid', 'label'], dtype='object')

# %%
def dropColumns(csv_file):
    #csv_file = csv_file[['filename', 'digit']]
    print(csv_file)
    print(csv_file.iloc[:2, :])   #First 5 Rows of the CSV File
    print("=============================")
    return csv_file

# %%
# concating male and felame CSV
totalTest_csv = [nT_csv, cT_csv, pT_csv, lT_csv]

mergedTest_csv = pd.concat(totalTest_csv)
print(len(mergedTest_csv))
# Out:
# 2368

# %%
# saving total csv of yest images
mergedTest_csv1=mergedTest_csv.sample(frac=1)
print(mergedTest_csv1)
mergedTest_csv1.to_csv('C:/Users/Raihan/Downloads/chestxray/data/testcsv.csv',index=False)
# Out:
#                    imageid  label
# 568   Lung_Opacity-668.png      3
# 516  Lung_Opacity-5605.png      3
# 358  Lung_Opacity-4115.png      3
# 9           COVID-1053.png      1
# 174     pneumonia2458.jpeg      2
# ..                     ...    ...
# 63   Lung_Opacity-1574.png      3
# 669        Normal-6826.png      0
# 294        Normal-3441.png      0
# 639        Normal-6551.png      0
# 266         COVID-3409.png      1
#
# [2368 rows x 2 columns]

# %% [markdown]
# ## Making CSV for train data

# %%
import os
import pandas 
a=os.listdir('C:/Users/Raihan/Downloads/chestxray/lungopacityResize/')
'''for i in a:
    print(i)
l=[]
'''

df = pandas.DataFrame(data={"imageid": a, "label": 3})
df.to_csv("C:/Users/Raihan/Downloads/chestxray/data/loTrain.csv", sep=',',index=False)
df
# Out:
#                     imageid  label
# 0        Lung_Opacity-1.png      3
# 1       Lung_Opacity-10.png      3
# 2      Lung_Opacity-100.png      3
# 3     Lung_Opacity-1001.png      3
# 4     Lung_Opacity-1002.png      3
# ...                     ...    ...
# 5406   Lung_Opacity-995.png      3
# 5407   Lung_Opacity-996.png      3
# 5408   Lung_Opacity-997.png      3
# 5409   Lung_Opacity-998.png      3
# 5410   Lung_Opacity-999.png      3
#
# [5411 rows x 2 columns]

# %%
import os
from os import path
import shutil
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision import datasets, transforms, models
import matplotlib
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns

# %%
#loading test CSV
mergedTest_csv1 = pd.read_csv('C:/Users/Raihan/Downloads/chestxray/data/testcsv.csv')

# %% [markdown]
# ## Visualing data and length of each class

# %%
from PIL import Image
data_dir = 'C:/Users/Raihan/Downloads/chestxray/normalResize'
name = os.listdir(data_dir)[50]
Image.open(data_dir+"/"+name)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=400x400 at 0x165BD4B0430>

# %%
src = 'C:/Users/Raihan/Downloads/chestxray/covidResize'
a = os.listdir(src)
print(len(a))
# Out:
# 3255

# %%
src = 'C:/Users/Raihan/Downloads/chestxray/normalResize'
a = os.listdir(src)
print(len(a))
# Out:
# 9173

# %%
src = 'C:/Users/Raihan/Downloads/chestxray/pneumoniaResize'
a = os.listdir(src)
print(len(a))
# Out:
# 3488

# %%
src = 'C:/Users/Raihan/Downloads/chestxray/lungopacityResize'
a = os.listdir(src)
print(len(a))
# Out:
# 5411

# %%
normalCsv = pd.read_csv('C:/Users/Raihan/Downloads/chestxray/data/normalTrain.csv')
normalCsv.columns
normalCsv.iloc[:10, 0:]
# Out:
#             imageid  label
# 0    Normal-100.png      0
# 1  Normal-10000.png      0
# 2  Normal-10002.png      0
# 3  Normal-10003.png      0
# 4  Normal-10004.png      0
# 5  Normal-10005.png      0
# 6  Normal-10006.png      0
# 7  Normal-10007.png      0
# 8  Normal-10008.png      0
# 9  Normal-10009.png      0

# %%
covidCsv = pd.read_csv('C:/Users/Raihan/Downloads/chestxray/data/covidTrain.csv')
covidCsv.columns
covidCsv.iloc[:10, 0:]
# Out:
#           imageid  label
# 0     COVID-1.png      1
# 1    COVID-10.png      1
# 2   COVID-100.png      1
# 3  COVID-1000.png      1
# 4  COVID-1001.png      1
# 5  COVID-1002.png      1
# 6  COVID-1004.png      1
# 7  COVID-1005.png      1
# 8  COVID-1006.png      1
# 9  COVID-1008.png      1

# %%
pneuCsv = pd.read_csv('C:/Users/Raihan/Downloads/chestxray/data/pneumoniaTrain.csv')
pneuCsv.columns
pneuCsv.iloc[:10, 0:]
# Out:
#               imageid  label
# 0     pneumonia0.jpeg      2
# 1     pneumonia1.jpeg      2
# 2    pneumonia10.jpeg      2
# 3   pneumonia100.jpeg      2
# 4  pneumonia1001.jpeg      2
# 5  pneumonia1003.jpeg      2
# 6  pneumonia1004.jpeg      2
# 7  pneumonia1005.jpeg      2
# 8  pneumonia1006.jpeg      2
# 9  pneumonia1007.jpeg      2

# %%
loCsv = pd.read_csv('C:/Users/Raihan/Downloads/chestxray/data/loTrain.csv')
loCsv.columns
loCsv.iloc[:10, 0:]
# Out:
#                  imageid  label
# 0     Lung_Opacity-1.png      3
# 1    Lung_Opacity-10.png      3
# 2   Lung_Opacity-100.png      3
# 3  Lung_Opacity-1001.png      3
# 4  Lung_Opacity-1002.png      3
# 5  Lung_Opacity-1003.png      3
# 6  Lung_Opacity-1004.png      3
# 7  Lung_Opacity-1005.png      3
# 8  Lung_Opacity-1006.png      3
# 9  Lung_Opacity-1007.png      3

# %%
PATH = 'C:/Users/Raihan/Downloads/chestxray/data/'

# %%
def showRawTrainingSamples(csv_filename):
    df = pd.read_csv(PATH + csv_filename)
    print(csv_filename)
    print(df.columns)
    return df

# %%
n_csv = showRawTrainingSamples('normalTrain.csv')
c_csv = showRawTrainingSamples('covidTrain.csv')
p_csv = showRawTrainingSamples('pneumoniaTrain.csv')
l_csv = showRawTrainingSamples('loTrain.csv')
# Out:
# normalTrain.csv
# Index(['imageid', 'label'], dtype='object')
# covidTrain.csv
# Index(['imageid', 'label'], dtype='object')
# pneumoniaTrain.csv
# Index(['imageid', 'label'], dtype='object')
# loTrain.csv
# Index(['imageid', 'label'], dtype='object')

# %%
def dropColumns(csv_file):
    #csv_file = csv_file[['filename', 'digit']]
    print(csv_file)
    print(csv_file.iloc[:2, :])   #First 5 Rows of the CSV File
    print("=============================")
    return csv_file

# %%
n_csv = dropColumns(n_csv)
c_csv = dropColumns(c_csv)
p_csv = dropColumns(p_csv)
l_csv = dropColumns(l_csv)
# Out:
#                imageid  label
# 0       Normal-100.png      0
# 1     Normal-10000.png      0
# 2     Normal-10002.png      0
# 3     Normal-10003.png      0
# 4     Normal-10004.png      0
# ...                ...    ...
# 9168   Normal-9995.png      0
# 9169   Normal-9996.png      0
# 9170   Normal-9997.png      0
# 9171   Normal-9998.png      0
# 9172   Normal-9999.png      0
#
# [9173 rows x 2 columns]
#             imageid  label
# 0    Normal-100.png      0
# 1  Normal-10000.png      0
# ...
#              imageid  label
# 0        COVID-1.png      1
# 1       COVID-10.png      1
# 2      COVID-100.png      1
# 3     COVID-1000.png      1
# 4     COVID-1001.png      1
# ...              ...    ...
# 3250   COVID-995.png      1
# 3251   COVID-996.png      1
# 3252   COVID-997.png      1
# 3253   COVID-998.png      1
# 3254   COVID-999.png      1
#
# [3255 rows x 2 columns]
#         imageid  label
# 0   COVID-1.png      1
# 1  COVID-10.png      1
# ...
#                  imageid  label
# ...

# %%
# concating 4 CSVs of training data
total_csv = [n_csv, c_csv, p_csv, l_csv]

merged_csv = pd.concat(total_csv)
print(len(merged_csv))
# Out:
# 21327

# %%
merged_csv1=merged_csv.sample(frac=1)
print(merged_csv1)
# Out:
#                     imageid  label
# 3291        Normal-4119.png      0
# 2314     pneumonia3328.jpeg      2
# 1634     pneumonia2645.jpeg      2
# 2914          COVID-660.png      1
# 876          COVID-1888.png      1
# ...                     ...    ...
# 4104  Lung_Opacity-5116.png      3
# 1173         COVID-2179.png      1
# 703          COVID-1709.png      1
# 1542     pneumonia2550.jpeg      2
# 513          COVID-1513.png      1
#
# [21327 rows x 2 columns]

# %%
PATH = 'C:/Users/Raihan/Downloads/chestxray/'

# %%
##Making train folder
TRAIN_PATH = 'C:/Users/Raihan/Downloads/chestxray/data/train'
Test_Path='C:/Users/Raihan/Downloads/chestxray/data/test'

# %%
def processImages(folder_name):
    src = PATH + folder_name + '/'
    dir_folders = os.listdir(src)
    for dir_name in dir_folders:
        file_name = os.path.join(src, dir_name)
        if os.path.isfile(file_name):
            shutil.copy(file_name, TRAIN_PATH)

# %%
processImages('normalResize')
print('N Done')
processImages('covidResize')
print('C Done')
processImages('pneumoniaResize')
print('P Done')
processImages('lungopacityResize')
print('L Done')
# Out:
# N Done
# C Done
# P Done
# L Done

# %%
class Dataset(Dataset):
    def __init__(self, df, root, transform=None):
        self.data = df
        self.root = root
        self.transform = transform
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        item = self.data.iloc[index]
        
        path = self.root + "/" + item[0]
        image = Image.open(path).convert('L')
        label = item[1]
        
        if self.transform is not None:
            image = self.transform(image)
            
        return image, label

# %%
#Normalizing Dataset
mean = [0.5,]
std = [0.5, ]

train_transform = transforms.Compose([
    transforms.Resize(400),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
])

valid_transform = transforms.Compose([
        transforms.Resize(400),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
        transforms.Resize(400),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
])


train_data  = Dataset(merged_csv1, TRAIN_PATH, train_transform)
valid_data = Dataset(merged_csv1, TRAIN_PATH, valid_transform)
test_data = Dataset(mergedTest_csv1, Test_Path, test_transform)

print("Trainig Samples: ",len(train_data))
print("Validation Samples: ",len(valid_data))
print("Test Samples: ",len(test_data))
# Out:
# Trainig Samples:  21327
# Validation Samples:  21327
# Test Samples:  2368

# %%
## Displaying a Image

import matplotlib.pyplot as plt 
import numpy as np

show_img = train_data[5000][0].numpy().reshape(400, 400)
plt.imshow(show_img, cmap='gray')

# %%
## Displaying another Image with label

print("Label:")
print(train_data[2][1])

show_img = train_data[2000][0].numpy().reshape(400, 400)
plt.imshow(show_img, cmap='gray')
# Out:
# Label:
# 2

# %%
# One Image Size
print(train_data[0][0].size())
print(train_data[0][0].numpy().shape)
# First Image Label
print(train_data[59][1])
# Out:
# torch.Size([1, 400, 400])
# (1, 400, 400)
# 2

# %% [markdown]
# ## Desigining models with different combinations
#
# Combination| batch size | epochs | num_hidden | Learning Rate | NN-Layer | Activations  |
# -----------|------------|--------|------------|---------------|----------|--------------|
#     1      |     130    |   30   |     50     |      0.001    |     3    |     ReLU     |
#     2      |     100    |   23   |     50     |      0.001    |     3    |     ReLU     |
#     3      |     150    |   35   |     50     |      0.001    |     3    |     ReLU     |
#     4      |     100    |   23   |     80     |      0.001    |     3    |     ReLU     |
#     5      |     100    |   23   |     20     |      0.001    |     3    |     ReLU     |
#     6      |     100    |   23   |     20     |      0.0001   |     3    |     ReLU     |
#     7      |     100    |   23   |     20     |      0.01     |     3    |     ReLU     |
#     8      |     100    |   23   |     20     |      0.001    |     2    |     ReLU     |
#     9      |     100    |   23   |     20     |      0.001    |     4    |     ReLU     |
#     10     |     100    |   23   |     20     |      0.001    |     3    |     RReLU    |
#     11     |     100    |   23   |     20     |      0.001    |     3    |     SELU     |
#     12     |     100    |   23   |     20     |      0.001    |     3    |  3 lyr different|
#
#
#  - combination 12 - 3 lyr different means  1st lyr-RRelu, 2nd lyr-Relu, 3rd lyr-SELU

# %% [markdown]
# # Combination 1

# %%
# Hyperparameters

batch_size = 130
num_iters = 5000
num_hidden = 50
input_dim = 400*400 # num_features = 784
output_dim = 4
save_model = True

learning_rate = 0.001


# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = num_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
print(len(train_data))
# Out:
# 30
# 21327

# %%
#batch size
#batch_size = 32

# split data 20% for testing
val_size = 0.1

# obtain training indices that will be used for validation
num_train = len(train_data)

# mix data
# index of num of train
indices = list(range(num_train))
# random the index
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
# divied into two part
train_idx, val_idx = indices[split:], indices[:split]

# define the sampler
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

# prepare loaders
train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size,
    sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    valid_data, batch_size=batch_size,
    sampler=val_sampler)

test_loader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size)

print("Train dataloader:{}".format(len(train_loader)))
print("val dataloader:{}".format(len(val_loader)))
print("Test dataloader:{}".format(len(test_loader)))
# Out:
# Train dataloader:148
# val dataloader:17
# Test dataloader:19

# %%
class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden):
        super().__init__()
        ### 1st hidden layer: 784 --> 100
        self.linear_1 = nn.Linear(input_size, num_hidden)
        ### Non-linearity in 1st hidden layer
        self.relu_1 = nn.ReLU()

        ### 2nd hidden layer: 100 --> 100
        self.linear_2 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 2nd hidden layer
        self.relu_2 = nn.ReLU()

        ### 3rd hidden layer: 100 --> 100
        self.linear_3 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 3rd hidden layer
        self.relu_3 = nn.ReLU()

        ### Output layer: 100 --> 10
        self.linear_out = nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        ### 1st hidden layer
        out  = self.linear_1(x)
        ### Non-linearity in 1st hidden layer
        out = self.relu_1(out)
        
        ### 2nd hidden layer
        out  = self.linear_2(out)
        ### Non-linearity in 2nd hidden layer
        out = self.relu_2(out)

        ### 3rd hidden layer
        out  = self.linear_3(out)
        ### Non-linearity in 3rd hidden layer
        out = self.relu_3(out)
        
        # Linear layer (output)
        probas  = self.linear_out(out)
        return probas

# %%
# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim,
                               num_hidden = num_hidden)
# To enable GPU
model.to(device)
# Out:
# DeepNeuralNetworkModel(
#   (linear_1): Linear(in_features=160000, out_features=50, bias=True)
#   (relu_1): ReLU()
#   (linear_2): Linear(in_features=50, out_features=50, bias=True)
#   (relu_2): ReLU()
#   (linear_3): Linear(in_features=50, out_features=50, bias=True)
#   (relu_3): ReLU()
#   (linear_out): Linear(in_features=50, out_features=4, bias=True)
# )

# %%
# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in range(1, num_epochs+1):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch=X_train_batch.view(X_train_batch.shape[0],-1)  
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch=X_val_batch.view(X_val_batch.shape[0],-1) 
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
# Epoch 001: | Train Loss: 0.72697 | Val Loss: 0.56635 | Train Acc: 71.628| Val Acc: 78.118
# Exception ignored in: <function tqdm.__del__ at 0x000001C2725E3DC0>
# Traceback (most recent call last):
#   File "C:\Users\Raihan\Anaconda3\envs\pytorch\lib\site-packages\tqdm\std.py", line 1124, in __del__
#     self.close()
#   File "C:\Users\Raihan\Anaconda3\envs\pytorch\lib\site-packages\tqdm\notebook.py", line 271, in close
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Epoch 002: | Train Loss: 0.54784 | Val Loss: 0.57085 | Train Acc: 79.101| Val Acc: 77.882
# Epoch 003: | Train Loss: 0.48260 | Val Loss: 0.52635 | Train Acc: 81.743| Val Acc: 81.118
# Epoch 004: | Train Loss: 0.44047 | Val Loss: 0.49598 | Train Acc: 83.473| Val Acc: 82.706
# Epoch 005: | Train Loss: 0.41639 | Val Loss: 0.45156 | Train Acc: 84.284| Val Acc: 84.118
# ...

# %%
if save_model is True:
    # Saves only parameters
    # wights & biases
    torch.save(model.state_dict(), 'C:/Users/Raihan/Downloads/chestxray/data/model/combination1.pkl')

# %%
import seaborn as sns
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[892.  23.  15.  89.]
#  [ 65. 257.   3.  36.]
#  [  6.   3. 366.  12.]
#  [102.  11.   0. 488.]]

# %% [markdown]
# # Combination 2

# %%
# Hyperparameters

batch_size = 100
num_iters = 5000
num_hidden = 50
input_dim = 400*400 # num_features = 784
output_dim = 4
save_model = True

learning_rate = 0.001


# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = num_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
print(len(train_data))
# Out:
# 23
# 21327

# %%
#batch size
#batch_size = 32

# split data 20% for testing
val_size = 0.1

# obtain training indices that will be used for validation
num_train = len(train_data)

# mix data
# index of num of train
indices = list(range(num_train))
# random the index
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
# divied into two part
train_idx, val_idx = indices[split:], indices[:split]

# define the sampler
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

# prepare loaders
train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size,
    sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    valid_data, batch_size=batch_size,
    sampler=val_sampler)

test_loader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size)

print("Train dataloader:{}".format(len(train_loader)))
print("val dataloader:{}".format(len(val_loader)))
print("Test dataloader:{}".format(len(test_loader)))
# Out:
# Train dataloader:192
# val dataloader:22
# Test dataloader:24

# %%
class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden):
        super().__init__()
        ### 1st hidden layer: 784 --> 100
        self.linear_1 = nn.Linear(input_size, num_hidden)
        ### Non-linearity in 1st hidden layer
        self.relu_1 = nn.ReLU()

        ### 2nd hidden layer: 100 --> 100
        self.linear_2 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 2nd hidden layer
        self.relu_2 = nn.ReLU()

        ### 3rd hidden layer: 100 --> 100
        self.linear_3 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 3rd hidden layer
        self.relu_3 = nn.ReLU()

        ### Output layer: 100 --> 10
        self.linear_out = nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        ### 1st hidden layer
        out  = self.linear_1(x)
        ### Non-linearity in 1st hidden layer
        out = self.relu_1(out)
        
        ### 2nd hidden layer
        out  = self.linear_2(out)
        ### Non-linearity in 2nd hidden layer
        out = self.relu_2(out)

        ### 3rd hidden layer
        out  = self.linear_3(out)
        ### Non-linearity in 3rd hidden layer
        out = self.relu_3(out)
        
        # Linear layer (output)
        probas  = self.linear_out(out)
        return probas

# %%
# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim,
                               num_hidden = num_hidden)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in range(1, num_epochs+1):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch=X_train_batch.view(X_train_batch.shape[0],-1)  
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch=X_val_batch.view(X_val_batch.shape[0],-1) 
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
# Epoch 001: | Train Loss: 0.71218 | Val Loss: 0.53142 | Train Acc: 72.354| Val Acc: 80.773
# Epoch 002: | Train Loss: 0.53470 | Val Loss: 0.55953 | Train Acc: 79.562| Val Acc: 79.091
# Epoch 003: | Train Loss: 0.46162 | Val Loss: 0.53439 | Train Acc: 82.562| Val Acc: 81.136
# Epoch 004: | Train Loss: 0.43520 | Val Loss: 0.49354 | Train Acc: 83.547| Val Acc: 83.409
# Epoch 005: | Train Loss: 0.40939 | Val Loss: 0.46138 | Train Acc: 84.521| Val Acc: 84.727
# Epoch 006: | Train Loss: 0.38292 | Val Loss: 0.43591 | Train Acc: 85.641| Val Acc: 84.909
# Epoch 007: | Train Loss: 0.35706 | Val Loss: 0.46721 | Train Acc: 86.635| Val Acc: 83.818
# Epoch 008: | Train Loss: 0.34717 | Val Loss: 0.42726 | Train Acc: 87.271| Val Acc: 85.273
# Epoch 009: | Train Loss: 0.32246 | Val Loss: 0.42564 | Train Acc: 88.182| Val Acc: 86.364
# Epoch 010: | Train Loss: 0.32361 | Val Loss: 0.48112 | Train Acc: 87.927| Val Acc: 84.000
# ...

# %%
if save_model is True:
    # Saves only parameters
    # wights & biases
    torch.save(model.state_dict(), 'C:/Users/Raihan/Downloads/chestxray/data/model/combination2.pkl')

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[926.  13.  18.  62.]
#  [ 67. 252.   1.  41.]
#  [  6.   4. 371.   6.]
#  [125.   9.   3. 464.]]

# %% [markdown]
# # Combination 3

# %%
# Hyperparameters

batch_size = 150
num_iters = 5000
num_hidden = 50
input_dim = 400*400 # num_features = 784
output_dim = 4
save_model = True

learning_rate = 0.001


# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = num_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
print(len(train_data))
# Out:
# 35
# 21327

# %%
#batch size
#batch_size = 32

# split data 20% for testing
val_size = 0.1

# obtain training indices that will be used for validation
num_train = len(train_data)

# mix data
# index of num of train
indices = list(range(num_train))
# random the index
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
# divied into two part
train_idx, val_idx = indices[split:], indices[:split]

# define the sampler
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

# prepare loaders
train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size,
    sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    valid_data, batch_size=batch_size,
    sampler=val_sampler)

test_loader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size)

print("Train dataloader:{}".format(len(train_loader)))
print("val dataloader:{}".format(len(val_loader)))
print("Test dataloader:{}".format(len(test_loader)))
# Out:
# Train dataloader:128
# val dataloader:15
# Test dataloader:16

# %%
class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden):
        super().__init__()
        ### 1st hidden layer: 784 --> 100
        self.linear_1 = nn.Linear(input_size, num_hidden)
        ### Non-linearity in 1st hidden layer
        self.relu_1 = nn.ReLU()

        ### 2nd hidden layer: 100 --> 100
        self.linear_2 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 2nd hidden layer
        self.relu_2 = nn.ReLU()

        ### 3rd hidden layer: 100 --> 100
        self.linear_3 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 3rd hidden layer
        self.relu_3 = nn.ReLU()

        ### Output layer: 100 --> 10
        self.linear_out = nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        ### 1st hidden layer
        out  = self.linear_1(x)
        ### Non-linearity in 1st hidden layer
        out = self.relu_1(out)
        
        ### 2nd hidden layer
        out  = self.linear_2(out)
        ### Non-linearity in 2nd hidden layer
        out = self.relu_2(out)

        ### 3rd hidden layer
        out  = self.linear_3(out)
        ### Non-linearity in 3rd hidden layer
        out = self.relu_3(out)
        
        # Linear layer (output)
        probas  = self.linear_out(out)
        return probas

# %%
# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim,
                               num_hidden = num_hidden)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in range(1, num_epochs+1):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch=X_train_batch.view(X_train_batch.shape[0],-1)  
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch=X_val_batch.view(X_val_batch.shape[0],-1) 
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
# Epoch 001: | Train Loss: 0.75017 | Val Loss: 0.57226 | Train Acc: 71.172| Val Acc: 77.933
# Epoch 002: | Train Loss: 0.53802 | Val Loss: 0.52369 | Train Acc: 79.008| Val Acc: 79.667
# Epoch 003: | Train Loss: 0.47486 | Val Loss: 0.53266 | Train Acc: 82.188| Val Acc: 79.733
# Epoch 004: | Train Loss: 0.43794 | Val Loss: 0.51918 | Train Acc: 83.672| Val Acc: 81.200
# Epoch 005: | Train Loss: 0.40850 | Val Loss: 0.44830 | Train Acc: 84.742| Val Acc: 83.133
# Epoch 006: | Train Loss: 0.38089 | Val Loss: 0.47773 | Train Acc: 85.883| Val Acc: 82.467
# Epoch 007: | Train Loss: 0.35767 | Val Loss: 0.47974 | Train Acc: 86.594| Val Acc: 82.133
# Epoch 008: | Train Loss: 0.34215 | Val Loss: 0.44214 | Train Acc: 87.398| Val Acc: 83.867
# Epoch 009: | Train Loss: 0.33657 | Val Loss: 0.44886 | Train Acc: 87.430| Val Acc: 83.600
# Epoch 010: | Train Loss: 0.30972 | Val Loss: 0.44009 | Train Acc: 88.352| Val Acc: 84.800
# ...

# %%
if save_model is True:
    # Saves only parameters
    # wights & biases
    torch.save(model.state_dict(), 'C:/Users/Raihan/Downloads/chestxray/data/model/combination3.pkl')

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[915.  21.  13.  70.]
#  [ 83. 240.   5.  33.]
#  [  9.   2. 370.   6.]
#  [122.  17.   4. 458.]]

# %% [markdown]
# # Combination 4

# %%
# Hyperparameters

batch_size = 100
num_iters = 5000
num_hidden = 80
input_dim = 400*400 # num_features = 784
output_dim = 4
save_model = True

learning_rate = 0.001


# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = num_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
print(len(train_data))
# Out:
# 23
# 21327

# %%
#batch size
#batch_size = 32

# split data 20% for testing
val_size = 0.1

# obtain training indices that will be used for validation
num_train = len(train_data)

# mix data
# index of num of train
indices = list(range(num_train))
# random the index
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
# divied into two part
train_idx, val_idx = indices[split:], indices[:split]

# define the sampler
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

# prepare loaders
train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size,
    sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    valid_data, batch_size=batch_size,
    sampler=val_sampler)

test_loader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size)

print("Train dataloader:{}".format(len(train_loader)))
print("val dataloader:{}".format(len(val_loader)))
print("Test dataloader:{}".format(len(test_loader)))
# Out:
# Train dataloader:192
# val dataloader:22
# Test dataloader:24

# %%
class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden):
        super().__init__()
        ### 1st hidden layer: 784 --> 100
        self.linear_1 = nn.Linear(input_size, num_hidden)
        ### Non-linearity in 1st hidden layer
        self.relu_1 = nn.ReLU()

        ### 2nd hidden layer: 100 --> 100
        self.linear_2 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 2nd hidden layer
        self.relu_2 = nn.ReLU()

        ### 3rd hidden layer: 100 --> 100
        self.linear_3 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 3rd hidden layer
        self.relu_3 = nn.ReLU()

        ### Output layer: 100 --> 10
        self.linear_out = nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        ### 1st hidden layer
        out  = self.linear_1(x)
        ### Non-linearity in 1st hidden layer
        out = self.relu_1(out)
        
        ### 2nd hidden layer
        out  = self.linear_2(out)
        ### Non-linearity in 2nd hidden layer
        out = self.relu_2(out)

        ### 3rd hidden layer
        out  = self.linear_3(out)
        ### Non-linearity in 3rd hidden layer
        out = self.relu_3(out)
        
        # Linear layer (output)
        probas  = self.linear_out(out)
        return probas

# %%
# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim,
                               num_hidden = num_hidden)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in range(1, num_epochs+1):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch=X_train_batch.view(X_train_batch.shape[0],-1)  
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch=X_val_batch.view(X_val_batch.shape[0],-1) 
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
# Epoch 001: | Train Loss: 0.72675 | Val Loss: 0.52510 | Train Acc: 72.214| Val Acc: 80.273
# Epoch 002: | Train Loss: 0.54050 | Val Loss: 0.53615 | Train Acc: 79.385| Val Acc: 79.273
# Epoch 003: | Train Loss: 0.47662 | Val Loss: 0.44745 | Train Acc: 82.057| Val Acc: 82.227
# Epoch 004: | Train Loss: 0.43676 | Val Loss: 0.47477 | Train Acc: 83.453| Val Acc: 82.136
# Epoch 005: | Train Loss: 0.40574 | Val Loss: 0.41450 | Train Acc: 84.844| Val Acc: 84.818
# Epoch 006: | Train Loss: 0.38375 | Val Loss: 0.41163 | Train Acc: 85.583| Val Acc: 84.409
# Epoch 007: | Train Loss: 0.35568 | Val Loss: 0.42629 | Train Acc: 86.651| Val Acc: 84.773
# Epoch 008: | Train Loss: 0.34222 | Val Loss: 0.51728 | Train Acc: 87.286| Val Acc: 81.318
# Epoch 009: | Train Loss: 0.33484 | Val Loss: 0.42238 | Train Acc: 87.552| Val Acc: 84.227
# Epoch 010: | Train Loss: 0.30952 | Val Loss: 0.41586 | Train Acc: 88.344| Val Acc: 84.955
# ...

# %%
if save_model is True:
    # Saves only parameters
    # wights & biases
    torch.save(model.state_dict(), 'C:/Users/Raihan/Downloads/chestxray/data/model/combination4.pkl')

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[910.  25.   6.  78.]
#  [ 58. 267.   2.  34.]
#  [ 13.   3. 367.   4.]
#  [ 97.  15.   0. 489.]]

# %% [markdown]
# # Combination 5

# %%
# Hyperparameters

batch_size = 100
num_iters = 5000
num_hidden = 20
input_dim = 400*400 # num_features = 784
output_dim = 4
save_model = True

learning_rate = 0.001


# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = num_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
print(len(train_data))
# Out:
# 23
# 21327

# %%
#batch size
#batch_size = 32

# split data 20% for testing
val_size = 0.1

# obtain training indices that will be used for validation
num_train = len(train_data)

# mix data
# index of num of train
indices = list(range(num_train))
# random the index
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
# divied into two part
train_idx, val_idx = indices[split:], indices[:split]

# define the sampler
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

# prepare loaders
train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size,
    sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    valid_data, batch_size=batch_size,
    sampler=val_sampler)

test_loader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size)

print("Train dataloader:{}".format(len(train_loader)))
print("val dataloader:{}".format(len(val_loader)))
print("Test dataloader:{}".format(len(test_loader)))
# Out:
# Train dataloader:192
# val dataloader:22
# Test dataloader:24

# %%
class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden):
        super().__init__()
        ### 1st hidden layer: 784 --> 100
        self.linear_1 = nn.Linear(input_size, num_hidden)
        ### Non-linearity in 1st hidden layer
        self.relu_1 = nn.ReLU()

        ### 2nd hidden layer: 100 --> 100
        self.linear_2 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 2nd hidden layer
        self.relu_2 = nn.ReLU()

        ### 3rd hidden layer: 100 --> 100
        self.linear_3 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 3rd hidden layer
        self.relu_3 = nn.ReLU()

        ### Output layer: 100 --> 10
        self.linear_out = nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        ### 1st hidden layer
        out  = self.linear_1(x)
        ### Non-linearity in 1st hidden layer
        out = self.relu_1(out)
        
        ### 2nd hidden layer
        out  = self.linear_2(out)
        ### Non-linearity in 2nd hidden layer
        out = self.relu_2(out)

        ### 3rd hidden layer
        out  = self.linear_3(out)
        ### Non-linearity in 3rd hidden layer
        out = self.relu_3(out)
        
        # Linear layer (output)
        probas  = self.linear_out(out)
        return probas

# %%
# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim,
                               num_hidden = num_hidden)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in range(1, num_epochs+1):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch=X_train_batch.view(X_train_batch.shape[0],-1)  
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch=X_val_batch.view(X_val_batch.shape[0],-1) 
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
# Epoch 001: | Train Loss: 0.81828 | Val Loss: 0.65581 | Train Acc: 67.479| Val Acc: 74.091
# Epoch 002: | Train Loss: 0.65409 | Val Loss: 0.60134 | Train Acc: 73.922| Val Acc: 75.909
# Epoch 003: | Train Loss: 0.59104 | Val Loss: 0.60364 | Train Acc: 76.833| Val Acc: 75.818
# Epoch 004: | Train Loss: 0.54753 | Val Loss: 0.54966 | Train Acc: 79.026| Val Acc: 79.000
# Epoch 005: | Train Loss: 0.51748 | Val Loss: 0.51734 | Train Acc: 80.151| Val Acc: 79.636
# Epoch 006: | Train Loss: 0.48275 | Val Loss: 0.47374 | Train Acc: 81.964| Val Acc: 82.955
# Epoch 007: | Train Loss: 0.46193 | Val Loss: 0.49894 | Train Acc: 82.589| Val Acc: 81.545
# Epoch 008: | Train Loss: 0.45131 | Val Loss: 0.55022 | Train Acc: 82.781| Val Acc: 79.500
# Epoch 009: | Train Loss: 0.43646 | Val Loss: 0.51752 | Train Acc: 83.766| Val Acc: 81.409
# Epoch 010: | Train Loss: 0.41851 | Val Loss: 0.47691 | Train Acc: 84.281| Val Acc: 82.773
# ...

# %%
if save_model is True:
    # Saves only parameters
    # wights & biases
    torch.save(model.state_dict(), 'C:/Users/Raihan/Downloads/chestxray/data/model/combination5.pkl')

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[913.  25.  15.  66.]
#  [ 85. 239.   6.  31.]
#  [ 15.   2. 367.   3.]
#  [115.  11.   3. 472.]]

# %% [markdown]
# # Combination 6

# %%
# Hyperparameters

batch_size = 100
num_iters = 5000
num_hidden = 20
input_dim = 400*400 # num_features = 784
output_dim = 4
save_model = True

learning_rate = 0.0001


# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = num_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
print(len(train_data))
# Out:
# 23
# 21327

# %%
#batch size
#batch_size = 32

# split data 20% for testing
val_size = 0.1

# obtain training indices that will be used for validation
num_train = len(train_data)

# mix data
# index of num of train
indices = list(range(num_train))
# random the index
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
# divied into two part
train_idx, val_idx = indices[split:], indices[:split]

# define the sampler
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

# prepare loaders
train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size,
    sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    valid_data, batch_size=batch_size,
    sampler=val_sampler)

test_loader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size)

print("Train dataloader:{}".format(len(train_loader)))
print("val dataloader:{}".format(len(val_loader)))
print("Test dataloader:{}".format(len(test_loader)))
# Out:
# Train dataloader:192
# val dataloader:22
# Test dataloader:24

# %%
class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden):
        super().__init__()
        ### 1st hidden layer: 784 --> 100
        self.linear_1 = nn.Linear(input_size, num_hidden)
        ### Non-linearity in 1st hidden layer
        self.relu_1 = nn.ReLU()

        ### 2nd hidden layer: 100 --> 100
        self.linear_2 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 2nd hidden layer
        self.relu_2 = nn.ReLU()

        ### 3rd hidden layer: 100 --> 100
        self.linear_3 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 3rd hidden layer
        self.relu_3 = nn.ReLU()

        ### Output layer: 100 --> 10
        self.linear_out = nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        ### 1st hidden layer
        out  = self.linear_1(x)
        ### Non-linearity in 1st hidden layer
        out = self.relu_1(out)
        
        ### 2nd hidden layer
        out  = self.linear_2(out)
        ### Non-linearity in 2nd hidden layer
        out = self.relu_2(out)

        ### 3rd hidden layer
        out  = self.linear_3(out)
        ### Non-linearity in 3rd hidden layer
        out = self.relu_3(out)
        
        # Linear layer (output)
        probas  = self.linear_out(out)
        return probas

# %%
# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim,
                               num_hidden = num_hidden)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in range(1, num_epochs+1):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch=X_train_batch.view(X_train_batch.shape[0],-1)  
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch=X_val_batch.view(X_val_batch.shape[0],-1) 
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
# Epoch 001: | Train Loss: 0.79474 | Val Loss: 0.66049 | Train Acc: 67.995| Val Acc: 73.409
# Epoch 002: | Train Loss: 0.62181 | Val Loss: 0.57520 | Train Acc: 75.703| Val Acc: 79.136
# Epoch 003: | Train Loss: 0.55372 | Val Loss: 0.53637 | Train Acc: 78.552| Val Acc: 79.273
# Epoch 004: | Train Loss: 0.51503 | Val Loss: 0.52997 | Train Acc: 80.083| Val Acc: 79.636
# Epoch 005: | Train Loss: 0.47545 | Val Loss: 0.52404 | Train Acc: 81.859| Val Acc: 80.364
# Epoch 006: | Train Loss: 0.44932 | Val Loss: 0.48113 | Train Acc: 83.214| Val Acc: 81.727
# Epoch 007: | Train Loss: 0.42822 | Val Loss: 0.46919 | Train Acc: 83.802| Val Acc: 82.364
# Epoch 008: | Train Loss: 0.41190 | Val Loss: 0.47001 | Train Acc: 84.557| Val Acc: 82.227
# Epoch 009: | Train Loss: 0.39669 | Val Loss: 0.45296 | Train Acc: 85.286| Val Acc: 82.727
# Epoch 010: | Train Loss: 0.37729 | Val Loss: 0.47197 | Train Acc: 86.089| Val Acc: 82.773
# ...

# %%
if save_model is True:
    # Saves only parameters
    # wights & biases
    torch.save(model.state_dict(), 'C:/Users/Raihan/Downloads/chestxray/data/model/combination6.pkl')

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[907.  22.   8.  82.]
#  [ 69. 247.   1.  44.]
#  [  8.   4. 369.   6.]
#  [105.  18.   3. 475.]]

# %% [markdown]
# # Combination 7

# %%
# Hyperparameters

batch_size = 100
num_iters = 5000
num_hidden = 20
input_dim = 400*400 # num_features = 784
output_dim = 4
save_model = True

learning_rate = 0.01


# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = num_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
print(len(train_data))
# Out:
# 23
# 21327

# %%
#batch size
#batch_size = 32

# split data 20% for testing
val_size = 0.1

# obtain training indices that will be used for validation
num_train = len(train_data)

# mix data
# index of num of train
indices = list(range(num_train))
# random the index
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
# divied into two part
train_idx, val_idx = indices[split:], indices[:split]

# define the sampler
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

# prepare loaders
train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size,
    sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    valid_data, batch_size=batch_size,
    sampler=val_sampler)

test_loader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size)

print("Train dataloader:{}".format(len(train_loader)))
print("val dataloader:{}".format(len(val_loader)))
print("Test dataloader:{}".format(len(test_loader)))
# Out:
# Train dataloader:192
# val dataloader:22
# Test dataloader:24

# %%
class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden):
        super().__init__()
        ### 1st hidden layer: 784 --> 100
        self.linear_1 = nn.Linear(input_size, num_hidden)
        ### Non-linearity in 1st hidden layer
        self.relu_1 = nn.ReLU()

        ### 2nd hidden layer: 100 --> 100
        self.linear_2 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 2nd hidden layer
        self.relu_2 = nn.ReLU()

        ### 3rd hidden layer: 100 --> 100
        self.linear_3 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 3rd hidden layer
        self.relu_3 = nn.ReLU()

        ### Output layer: 100 --> 10
        self.linear_out = nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        ### 1st hidden layer
        out  = self.linear_1(x)
        ### Non-linearity in 1st hidden layer
        out = self.relu_1(out)
        
        ### 2nd hidden layer
        out  = self.linear_2(out)
        ### Non-linearity in 2nd hidden layer
        out = self.relu_2(out)

        ### 3rd hidden layer
        out  = self.linear_3(out)
        ### Non-linearity in 3rd hidden layer
        out = self.relu_3(out)
        
        # Linear layer (output)
        probas  = self.linear_out(out)
        return probas

# %%
# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim,
                               num_hidden = num_hidden)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in range(1, num_epochs+1):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch=X_train_batch.view(X_train_batch.shape[0],-1)  
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch=X_val_batch.view(X_val_batch.shape[0],-1) 
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
# Epoch 001: | Train Loss: 1.17812 | Val Loss: 0.71081 | Train Acc: 62.943| Val Acc: 71.409
# Epoch 002: | Train Loss: 0.68317 | Val Loss: 0.74093 | Train Acc: 73.344| Val Acc: 71.227
# Epoch 003: | Train Loss: 0.63898 | Val Loss: 0.68191 | Train Acc: 75.495| Val Acc: 75.045
# Epoch 004: | Train Loss: 0.60532 | Val Loss: 0.66776 | Train Acc: 76.948| Val Acc: 74.773
# Epoch 005: | Train Loss: 0.56412 | Val Loss: 0.61704 | Train Acc: 78.495| Val Acc: 77.682
# Epoch 006: | Train Loss: 0.54494 | Val Loss: 0.53257 | Train Acc: 79.604| Val Acc: 80.273
# Epoch 007: | Train Loss: 0.52464 | Val Loss: 0.59014 | Train Acc: 80.609| Val Acc: 79.227
# Epoch 008: | Train Loss: 0.51599 | Val Loss: 0.56682 | Train Acc: 80.964| Val Acc: 78.455
# Epoch 009: | Train Loss: 0.49146 | Val Loss: 0.57664 | Train Acc: 81.870| Val Acc: 79.636
# Epoch 010: | Train Loss: 0.48064 | Val Loss: 0.53766 | Train Acc: 82.406| Val Acc: 81.545
# ...

# %%
if save_model is True:
    # Saves only parameters
    # wights & biases
    torch.save(model.state_dict(), 'C:/Users/Raihan/Downloads/chestxray/data/model/combination7.pkl')

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[921.  61.   7.  30.]
#  [ 70. 273.   1.  17.]
#  [ 11.  11. 364.   1.]
#  [142.  94.   6. 359.]]

# %% [markdown]
# # Combination 8

# %%
# Hyperparameters

batch_size = 100
num_iters = 5000
num_hidden = 20
input_dim = 400*400 # num_features = 784
output_dim = 4
save_model = True

learning_rate = 0.001


# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = num_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
print(len(train_data))
# Out:
# 23
# 21327

# %%
#batch size
#batch_size = 32

# split data 20% for testing
val_size = 0.1

# obtain training indices that will be used for validation
num_train = len(train_data)

# mix data
# index of num of train
indices = list(range(num_train))
# random the index
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
# divied into two part
train_idx, val_idx = indices[split:], indices[:split]

# define the sampler
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

# prepare loaders
train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size,
    sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    valid_data, batch_size=batch_size,
    sampler=val_sampler)

test_loader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size)

print("Train dataloader:{}".format(len(train_loader)))
print("val dataloader:{}".format(len(val_loader)))
print("Test dataloader:{}".format(len(test_loader)))
# Out:
# Train dataloader:192
# val dataloader:22
# Test dataloader:24

# %%
class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden):
        super().__init__()
        ### 1st hidden layer: 784 --> 100
        self.linear_1 = nn.Linear(input_size, num_hidden)
        ### Non-linearity in 1st hidden layer
        self.relu_1 = nn.ReLU()

        ### 2nd hidden layer: 100 --> 100
        self.linear_2 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 2nd hidden layer
        self.relu_2 = nn.ReLU()


        ### Output layer: 100 --> 10
        self.linear_out = nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        ### 1st hidden layer
        out  = self.linear_1(x)
        ### Non-linearity in 1st hidden layer
        out = self.relu_1(out)
        
        ### 2nd hidden layer
        out  = self.linear_2(out)
        ### Non-linearity in 2nd hidden layer
        out = self.relu_2(out)

        
        # Linear layer (output)
        probas  = self.linear_out(out)
        return probas

# %%
# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim,
                               num_hidden = num_hidden)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in range(1, num_epochs+1):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch=X_train_batch.view(X_train_batch.shape[0],-1)  
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch=X_val_batch.view(X_val_batch.shape[0],-1) 
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
# Epoch 001: | Train Loss: 0.90547 | Val Loss: 0.78436 | Train Acc: 64.141| Val Acc: 71.045
# Epoch 002: | Train Loss: 0.69856 | Val Loss: 0.66757 | Train Acc: 72.667| Val Acc: 73.545
# Epoch 003: | Train Loss: 0.64734 | Val Loss: 0.68223 | Train Acc: 74.948| Val Acc: 73.682
# Epoch 004: | Train Loss: 0.60458 | Val Loss: 0.59831 | Train Acc: 77.172| Val Acc: 77.545
# Epoch 005: | Train Loss: 0.57183 | Val Loss: 0.59108 | Train Acc: 78.281| Val Acc: 78.455
# Epoch 006: | Train Loss: 0.55112 | Val Loss: 0.56167 | Train Acc: 79.370| Val Acc: 79.955
# Epoch 007: | Train Loss: 0.53101 | Val Loss: 0.53415 | Train Acc: 79.932| Val Acc: 79.545
# Epoch 008: | Train Loss: 0.51044 | Val Loss: 0.54013 | Train Acc: 80.792| Val Acc: 79.955
# Epoch 009: | Train Loss: 0.50362 | Val Loss: 0.56089 | Train Acc: 81.266| Val Acc: 79.045
# Epoch 010: | Train Loss: 0.49078 | Val Loss: 0.52183 | Train Acc: 81.609| Val Acc: 80.727
# ...

# %%
if save_model is True:
    # Saves only parameters
    # wights & biases
    torch.save(model.state_dict(), 'C:/Users/Raihan/Downloads/chestxray/data/model/combination8.pkl')

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[916.  29.  14.  60.]
#  [ 99. 217.   5.  40.]
#  [ 11.   4. 370.   2.]
#  [152.  30.   7. 412.]]

# %% [markdown]
# # Combination 9

# %%
# Hyperparameters

batch_size = 100
num_iters = 5000
num_hidden = 20
input_dim = 400*400 # num_features = 784
output_dim = 4
save_model = True

learning_rate = 0.001


# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = num_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
print(len(train_data))
# Out:
# 23
# 21327

# %%
#batch size
#batch_size = 32

# split data 20% for testing
val_size = 0.1

# obtain training indices that will be used for validation
num_train = len(train_data)

# mix data
# index of num of train
indices = list(range(num_train))
# random the index
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
# divied into two part
train_idx, val_idx = indices[split:], indices[:split]

# define the sampler
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

# prepare loaders
train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size,
    sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    valid_data, batch_size=batch_size,
    sampler=val_sampler)

test_loader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size)

print("Train dataloader:{}".format(len(train_loader)))
print("val dataloader:{}".format(len(val_loader)))
print("Test dataloader:{}".format(len(test_loader)))
# Out:
# Train dataloader:192
# val dataloader:22
# Test dataloader:24

# %%
class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden):
        super().__init__()
        ### 1st hidden layer: 784 --> 100
        self.linear_1 = nn.Linear(input_size, num_hidden)
        ### Non-linearity in 1st hidden layer
        self.relu_1 = nn.ReLU()

        ### 2nd hidden layer: 100 --> 100
        self.linear_2 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 2nd hidden layer
        self.relu_2 = nn.ReLU()

        ### 3rd hidden layer: 100 --> 100
        self.linear_3 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 3rd hidden layer
        self.relu_3 = nn.ReLU()
        
        ### 4th hidden layer: 100 --> 100
        self.linear_4 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 4th hidden layer
        self.relu_4 = nn.ReLU()

        ### Output layer: 100 --> 10
        self.linear_out = nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        ### 1st hidden layer
        out  = self.linear_1(x)
        ### Non-linearity in 1st hidden layer
        out = self.relu_1(out)
        
        ### 2nd hidden layer
        out  = self.linear_2(out)
        ### Non-linearity in 2nd hidden layer
        out = self.relu_2(out)

        ### 3rd hidden layer
        out  = self.linear_3(out)
        ### Non-linearity in 3rd hidden layer
        out = self.relu_3(out)
        
        ### 4th hidden layer
        out  = self.linear_4(out)
        ### Non-linearity in 4th hidden layer
        out = self.relu_4(out)
        
        # Linear layer (output)
        probas  = self.linear_out(out)
        return probas

# %%
# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim,
                               num_hidden = num_hidden)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in range(1, num_epochs+1):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch=X_train_batch.view(X_train_batch.shape[0],-1)  
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch=X_val_batch.view(X_val_batch.shape[0],-1) 
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
# Epoch 001: | Train Loss: 0.72760 | Val Loss: 0.58524 | Train Acc: 70.792| Val Acc: 76.864
# Epoch 002: | Train Loss: 0.56006 | Val Loss: 0.52170 | Train Acc: 78.339| Val Acc: 80.091
# Epoch 003: | Train Loss: 0.50176 | Val Loss: 0.49514 | Train Acc: 80.932| Val Acc: 81.273
# Epoch 004: | Train Loss: 0.46352 | Val Loss: 0.47108 | Train Acc: 82.349| Val Acc: 82.318
# Epoch 005: | Train Loss: 0.42415 | Val Loss: 0.45985 | Train Acc: 84.302| Val Acc: 83.455
# Epoch 006: | Train Loss: 0.39666 | Val Loss: 0.43983 | Train Acc: 85.021| Val Acc: 84.455
# Epoch 007: | Train Loss: 0.38258 | Val Loss: 0.44479 | Train Acc: 85.625| Val Acc: 84.136
# Epoch 008: | Train Loss: 0.37702 | Val Loss: 0.46521 | Train Acc: 85.833| Val Acc: 82.955
# Epoch 009: | Train Loss: 0.36614 | Val Loss: 0.44781 | Train Acc: 86.255| Val Acc: 84.182
# Epoch 010: | Train Loss: 0.35595 | Val Loss: 0.43951 | Train Acc: 86.615| Val Acc: 84.091
# ...

# %%
if save_model is True:
    # Saves only parameters
    # wights & biases
    torch.save(model.state_dict(), 'C:/Users/Raihan/Downloads/chestxray/data/model/combination9.pkl')

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[918.  43.  17.  41.]
#  [ 35. 305.   3.  18.]
#  [  9.   2. 373.   3.]
#  [131.  30.   3. 437.]]

# %% [markdown]
# # Combination 10

# %%
# Hyperparameters

batch_size = 100
num_iters = 5000
num_hidden = 20
input_dim = 400*400 # num_features = 784
output_dim = 4
save_model = True

learning_rate = 0.001


# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = num_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
print(len(train_data))
# Out:
# 23
# 21327

# %%
#batch size
#batch_size = 32

# split data 20% for testing
val_size = 0.1

# obtain training indices that will be used for validation
num_train = len(train_data)

# mix data
# index of num of train
indices = list(range(num_train))
# random the index
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
# divied into two part
train_idx, val_idx = indices[split:], indices[:split]

# define the sampler
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

# prepare loaders
train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size,
    sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    valid_data, batch_size=batch_size,
    sampler=val_sampler)

test_loader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size)

print("Train dataloader:{}".format(len(train_loader)))
print("val dataloader:{}".format(len(val_loader)))
print("Test dataloader:{}".format(len(test_loader)))
# Out:
# Train dataloader:192
# val dataloader:22
# Test dataloader:24

# %%
class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden):
        super().__init__()
        ### 1st hidden layer: 784 --> 100
        self.linear_1 = nn.Linear(input_size, num_hidden)
        ### Non-linearity in 1st hidden layer
        self.relu_1 = nn.RReLU()

        ### 2nd hidden layer: 100 --> 100
        self.linear_2 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 2nd hidden layer
        self.relu_2 = nn.RReLU()

        ### 3rd hidden layer: 100 --> 100
        self.linear_3 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 3rd hidden layer
        self.relu_3 = nn.RReLU()

        ### Output layer: 100 --> 10
        self.linear_out = nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        ### 1st hidden layer
        out  = self.linear_1(x)
        ### Non-linearity in 1st hidden layer
        out = self.relu_1(out)
        
        ### 2nd hidden layer
        out  = self.linear_2(out)
        ### Non-linearity in 2nd hidden layer
        out = self.relu_2(out)

        ### 3rd hidden layer
        out  = self.linear_3(out)
        ### Non-linearity in 3rd hidden layer
        out = self.relu_3(out)
        
        # Linear layer (output)
        probas  = self.linear_out(out)
        return probas

# %%
# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim,
                               num_hidden = num_hidden)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in range(1, num_epochs+1):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch=X_train_batch.view(X_train_batch.shape[0],-1)  
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch=X_val_batch.view(X_val_batch.shape[0],-1) 
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
# Epoch 001: | Train Loss: 0.76131 | Val Loss: 0.62042 | Train Acc: 70.406| Val Acc: 75.000
# Epoch 002: | Train Loss: 0.61350 | Val Loss: 0.57165 | Train Acc: 76.146| Val Acc: 78.818
# Epoch 003: | Train Loss: 0.53181 | Val Loss: 0.53701 | Train Acc: 79.448| Val Acc: 79.727
# Epoch 004: | Train Loss: 0.48960 | Val Loss: 0.51433 | Train Acc: 81.271| Val Acc: 81.136
# Epoch 005: | Train Loss: 0.45808 | Val Loss: 0.48546 | Train Acc: 82.526| Val Acc: 82.273
# Epoch 006: | Train Loss: 0.43566 | Val Loss: 0.45801 | Train Acc: 83.635| Val Acc: 83.091
# Epoch 007: | Train Loss: 0.40733 | Val Loss: 0.49243 | Train Acc: 84.609| Val Acc: 83.182
# Epoch 008: | Train Loss: 0.39736 | Val Loss: 0.46120 | Train Acc: 85.359| Val Acc: 82.909
# Epoch 009: | Train Loss: 0.38787 | Val Loss: 0.43624 | Train Acc: 85.604| Val Acc: 83.955
# Epoch 010: | Train Loss: 0.36291 | Val Loss: 0.43167 | Train Acc: 86.578| Val Acc: 84.545
# ...

# %%
if save_model is True:
    # Saves only parameters
    # wights & biases
    torch.save(model.state_dict(), 'C:/Users/Raihan/Downloads/chestxray/data/model/combination10.pkl')

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[917.  18.   8.  76.]
#  [ 71. 251.   4.  35.]
#  [ 13.   0. 370.   4.]
#  [122.  10.   3. 466.]]

# %% [markdown]
# # Combination 11

# %%
# Hyperparameters

batch_size = 100
num_iters = 5000
num_hidden = 20
input_dim = 400*400 # num_features = 784
output_dim = 4
save_model = True

learning_rate = 0.001


# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = num_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
print(len(train_data))
# Out:
# 23
# 21327

# %%
#batch size
#batch_size = 32

# split data 20% for testing
val_size = 0.1

# obtain training indices that will be used for validation
num_train = len(train_data)

# mix data
# index of num of train
indices = list(range(num_train))
# random the index
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
# divied into two part
train_idx, val_idx = indices[split:], indices[:split]

# define the sampler
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

# prepare loaders
train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size,
    sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    valid_data, batch_size=batch_size,
    sampler=val_sampler)

test_loader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size)

print("Train dataloader:{}".format(len(train_loader)))
print("val dataloader:{}".format(len(val_loader)))
print("Test dataloader:{}".format(len(test_loader)))
# Out:
# Train dataloader:192
# val dataloader:22
# Test dataloader:24

# %%
class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden):
        super().__init__()
        ### 1st hidden layer: 784 --> 100
        self.linear_1 = nn.Linear(input_size, num_hidden)
        ### Non-linearity in 1st hidden layer
        self.relu_1 = nn.SELU()

        ### 2nd hidden layer: 100 --> 100
        self.linear_2 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 2nd hidden layer
        self.relu_2 = nn.SELU()

        ### 3rd hidden layer: 100 --> 100
        self.linear_3 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 3rd hidden layer
        self.relu_3 = nn.SELU()

        ### Output layer: 100 --> 10
        self.linear_out = nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        ### 1st hidden layer
        out  = self.linear_1(x)
        ### Non-linearity in 1st hidden layer
        out = self.relu_1(out)
        
        ### 2nd hidden layer
        out  = self.linear_2(out)
        ### Non-linearity in 2nd hidden layer
        out = self.relu_2(out)

        ### 3rd hidden layer
        out  = self.linear_3(out)
        ### Non-linearity in 3rd hidden layer
        out = self.relu_3(out)
        
        # Linear layer (output)
        probas  = self.linear_out(out)
        return probas

# %%
# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim,
                               num_hidden = num_hidden)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in range(1, num_epochs+1):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch=X_train_batch.view(X_train_batch.shape[0],-1)  
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch=X_val_batch.view(X_val_batch.shape[0],-1) 
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
# Epoch 001: | Train Loss: 0.77071 | Val Loss: 0.66468 | Train Acc: 69.802| Val Acc: 73.682
# Epoch 002: | Train Loss: 0.59707 | Val Loss: 0.61185 | Train Acc: 76.849| Val Acc: 77.136
# Epoch 003: | Train Loss: 0.54119 | Val Loss: 0.53582 | Train Acc: 79.078| Val Acc: 79.682
# Epoch 004: | Train Loss: 0.52089 | Val Loss: 0.53284 | Train Acc: 80.068| Val Acc: 79.500
# Epoch 005: | Train Loss: 0.47588 | Val Loss: 0.51617 | Train Acc: 82.057| Val Acc: 80.591
# Epoch 006: | Train Loss: 0.45212 | Val Loss: 0.49929 | Train Acc: 82.562| Val Acc: 79.955
# Epoch 007: | Train Loss: 0.43973 | Val Loss: 0.50717 | Train Acc: 83.682| Val Acc: 80.818
# Epoch 008: | Train Loss: 0.42505 | Val Loss: 0.52960 | Train Acc: 84.016| Val Acc: 80.818
# Epoch 009: | Train Loss: 0.41525 | Val Loss: 0.49370 | Train Acc: 84.245| Val Acc: 81.682
# Epoch 010: | Train Loss: 0.41017 | Val Loss: 0.45004 | Train Acc: 84.453| Val Acc: 83.000
# ...

# %%
if save_model is True:
    # Saves only parameters
    # wights & biases
    torch.save(model.state_dict(), 'C:/Users/Raihan/Downloads/chestxray/data/model/combination11.pkl')

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[866.  33.  37.  83.]
#  [ 45. 267.   4.  45.]
#  [  3.   2. 378.   4.]
#  [ 86.  24.   5. 486.]]

# %% [markdown]
# # Combination 12

# %%
# Hyperparameters

batch_size = 100
num_iters = 5000
num_hidden = 20
input_dim = 400*400 # num_features = 784
output_dim = 4
save_model = True

learning_rate = 0.001


# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
num_epochs = num_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
print(len(train_data))
# Out:
# 23
# 21327

# %%
#batch size
#batch_size = 32

# split data 20% for testing
val_size = 0.1

# obtain training indices that will be used for validation
num_train = len(train_data)

# mix data
# index of num of train
indices = list(range(num_train))
# random the index
np.random.shuffle(indices)
split = int(np.floor(val_size * num_train))
# divied into two part
train_idx, val_idx = indices[split:], indices[:split]

# define the sampler
train_sampler = SubsetRandomSampler(train_idx)
val_sampler = SubsetRandomSampler(val_idx)

# prepare loaders
train_loader = torch.utils.data.DataLoader(
    train_data, batch_size=batch_size,
    sampler=train_sampler)

val_loader = torch.utils.data.DataLoader(
    valid_data, batch_size=batch_size,
    sampler=val_sampler)

test_loader = torch.utils.data.DataLoader(
    test_data, batch_size=batch_size)

print("Train dataloader:{}".format(len(train_loader)))
print("val dataloader:{}".format(len(val_loader)))
print("Test dataloader:{}".format(len(test_loader)))
# Out:
# Train dataloader:192
# val dataloader:22
# Test dataloader:24

# %%
class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes, num_hidden):
        super().__init__()
        ### 1st hidden layer: 784 --> 100
        self.linear_1 = nn.Linear(input_size, num_hidden)
        ### Non-linearity in 1st hidden layer
        self.relu_1 = nn.RReLU()

        ### 2nd hidden layer: 100 --> 100
        self.linear_2 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 2nd hidden layer
        self.relu_2 = nn.ReLU()

        ### 3rd hidden layer: 100 --> 100
        self.linear_3 = nn.Linear(num_hidden, num_hidden)
        ### Non-linearity in 3rd hidden layer
        self.relu_3 = nn.SELU()

        ### Output layer: 100 --> 10
        self.linear_out = nn.Linear(num_hidden, num_classes)

    def forward(self, x):
        ### 1st hidden layer
        out  = self.linear_1(x)
        ### Non-linearity in 1st hidden layer
        out = self.relu_1(out)
        
        ### 2nd hidden layer
        out  = self.linear_2(out)
        ### Non-linearity in 2nd hidden layer
        out = self.relu_2(out)

        ### 3rd hidden layer
        out  = self.linear_3(out)
        ### Non-linearity in 3rd hidden layer
        out = self.relu_3(out)
        
        # Linear layer (output)
        probas  = self.linear_out(out)
        return probas

# %%
# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim,
                               num_hidden = num_hidden)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

# %%
accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in range(1, num_epochs+1):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch=X_train_batch.view(X_train_batch.shape[0],-1)  
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch=X_val_batch.view(X_val_batch.shape[0],-1) 
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
# Epoch 001: | Train Loss: 0.73628 | Val Loss: 0.58188 | Train Acc: 70.104| Val Acc: 77.455
# Epoch 002: | Train Loss: 0.56526 | Val Loss: 0.51754 | Train Acc: 77.682| Val Acc: 80.318
# Epoch 003: | Train Loss: 0.51201 | Val Loss: 0.55467 | Train Acc: 80.583| Val Acc: 79.045
# Epoch 004: | Train Loss: 0.48379 | Val Loss: 0.47947 | Train Acc: 81.620| Val Acc: 82.318
# Epoch 005: | Train Loss: 0.44659 | Val Loss: 0.46020 | Train Acc: 83.036| Val Acc: 83.182
# Epoch 006: | Train Loss: 0.42303 | Val Loss: 0.44272 | Train Acc: 83.755| Val Acc: 83.727
# Epoch 007: | Train Loss: 0.40581 | Val Loss: 0.44604 | Train Acc: 84.641| Val Acc: 84.364
# Epoch 008: | Train Loss: 0.38928 | Val Loss: 0.46348 | Train Acc: 85.396| Val Acc: 83.318
# Epoch 009: | Train Loss: 0.36950 | Val Loss: 0.42976 | Train Acc: 86.417| Val Acc: 84.455
# Epoch 010: | Train Loss: 0.35658 | Val Loss: 0.45520 | Train Acc: 86.755| Val Acc: 83.273
# ...

# %%
if save_model is True:
    # Saves only parameters
    # wights & biases
    torch.save(model.state_dict(), 'C:/Users/Raihan/Downloads/chestxray/data/model/combination12.pkl')

# %%
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')

# %%
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[908.  40.   8.  63.]
#  [ 53. 269.   0.  39.]
#  [  7.   8. 369.   3.]
#  [101.  19.   2. 479.]]

# %% [markdown]
# # Evaluating Models

# %%
load_model = True

if load_model is True:
    model.load_state_dict(torch.load('C:/Users/Raihan/Downloads/chestxray/data/model/combination12.pkl'))
    print('Trained Model Loaded')
# Out:
# Trained Model Loaded

# %%
import seaborn as sns
nb_classes = 4
confusion_matrix = np.zeros((nb_classes, nb_classes))
with torch.no_grad():
    for i, (inputs, classes) in enumerate(test_loader):
        inputs=inputs.view(inputs.shape[0],-1)
        inputs = inputs.to(device)
        classes = classes.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        for t, p in zip(classes.view(-1), preds.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1

plt.figure(figsize=(15,10))

class_names = ['normal', 'covid', 'pneumonia', 'lungOpacity']
df_cm = pd.DataFrame(confusion_matrix, index=class_names, columns=class_names).astype(int)
heatmap = sns.heatmap(df_cm, annot=True, fmt="d")

heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right',fontsize=15)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right',fontsize=15)
plt.ylabel('True label')
plt.xlabel('Predicted label')
print(confusion_matrix)
# Out:
# [[908.  40.   8.  63.]
#  [ 53. 269.   0.  39.]
#  [  7.   8. 369.   3.]
#  [101.  19.   2. 479.]]

# %%
class_accuracy=100*confusion_matrix.diagonal()/confusion_matrix.sum(1)
print(class_accuracy)
# Out:
# [89.10696762 74.51523546 95.34883721 79.70049917]

# %% [markdown]
# # Tables
#
# ### Accuracies obtained for different Hyperparameters
#
# - Hyperpatameters along with obtained training accuracy and validation accuracy are shown in the table below
#
# Combination| batch size | epochs | num_hidden | Learning Rate | NN-Layer | Activations  | Training Accuracy| Val Accuracy |
# -----------|------------|--------|------------|---------------|----------|--------------|------------------|--------------|
#     1      |     130    |   30   |     50     |      0.001    |     3    |     ReLU     |       93.730     |    85.353    |
#     2      |     100    |   23   |     50     |      0.001    |     3    |     ReLU     |       92.073     |    87.455    |
#     3      |     150    |   35   |     50     |      0.001    |     3    |     ReLU     |       93.773     |    83.867    |
#     4      |     100    |   23   |     80     |      0.001    |     3    |     ReLU     |       92.979     |    85.000    |
#     5      |     100    |   23   |     20     |      0.001    |     3    |     ReLU     |       92.979     |    85.318    |
#     6      |     100    |   23   |     20     |      0.0001   |     3    |     ReLU     |       88.531     |    84.727    |
#     7      |     100    |   23   |     20     |      0.01     |     3    |     ReLU     |       90.469     |    81.227    |
#     8      |     100    |   23   |     20     |      0.001    |     2    |     ReLU     |       83.068     |    81.045    |
#     9      |     100    |   23   |     20     |      0.001    |     4    |     ReLU     |       84.990     |    85.318    |
#     10     |     100    |   23   |     20     |      0.001    |     3    |     RReLU    |       90.901     |    85.273    |
#     11     |     100    |   23   |     20     |      0.001    |     3    |     SELU     |       90.641     |    84.273    |
#     12     |     100    |   23   |     20     |      0.001    |     3    |   3lyr diff  |    ***88.891***     |  ***86.591***    |
#
# - Accuracy of each class for different combinations are shown in the table below
#
# Combination| Normal Accuracy | Covid Accuracy | Pneumonia Accuracy | Lung Opacity Accuracy |
# -----------|-----------------|----------------|--------------------|-----------------------|
#      1     |      87.536     |      71.191    |        94.573      |          81.198       |
#      2     |      90.873     |      69.806    |        95.865      |          77.204       |
#      3     |      89.793     |      66.481    |        95.607      |          76.206       |
#      3     |      89.303     |      73.961    |        94.832      |          81.364       |
#      5     |      89.597     |      66.204    |        94.832      |          78.535       |
#      6     |      89.008     |      68.421    |        95.348      |          79.034       |
#      7     |      90.382     |      75.623    |        94.056      |          59.733       |
#      8     |      89.892     |      60.110    |        95.607      |          68.552       |
#      9     |      90.088     |      84.487    |        96.382      |          72.712       |
#      10    |      93.915     |      61.495    |        86.563      |          64.226       |
#      11    |      84.985     |      73.961    |        97.674      |          80.865       |
#      12    |   ***89.106***     |      ***74.515***    |        ***95.348***      |          ***79.700***       |
